# %%
from azure.identity import DefaultAzureCredential
from azure.storage.blob import BlobServiceClient
from io import BytesIO
import os
import sys
import yaml
import pandas as pd

#root_path = os.path.abspath(os.path.join(os.getcwd(), '.'))
#sys.path.append(root_path)

#from utils.data_collection import new_data_check, preprocess_df, make_train_test

# Don't forget to run ``az login`` in the command prompt and authenticate!

with open("../config.yml", "r") as f:
    config = yaml.safe_load(f)

ACCOUNT_URL = config['data']['account_url']
CONTAINER_NAME = config['data']['azure_container_name']
ONLINE_ADDRESS = config['data']['online_address']
DATA_PATH = config['data']['current_table']
OLD_DATA_PATH = config['data']['path_old_data']
default_credential = DefaultAzureCredential()

# Create the BlobServiceClient object
blob_service_client = BlobServiceClient(ACCOUNT_URL,
                                        credential=default_credential)
container_client = blob_service_client.get_container_client(CONTAINER_NAME)

# %%
blob_list = container_client.list_blobs()
files = []
for blob in blob_list:
    files.append(blob.name)

# %%
len(files)
# Out:
# 3

# %%
import re

results_oldies_search = []
results_data_path_search = []
oldies_paths = re.compile('oldies/')
data_path = re.compile(f'{DATA_PATH}')
older_dataframes_paths = []
for file in files:
    result_oldies = oldies_paths.search(file)
    if result_oldies is not None:
        older_dataframes_paths.append(file)
    result_data_path = data_path.search(file)
    results_oldies_search.append(result_oldies)
    results_data_path_search.append(result_data_path)

# %%
len([x for x in results_data_path_search if x is not None]) == 1
# Out:
# True

# %%
older_dataframes_paths
# Out:
# ['oldies/table_2020-05-01-2023-04-30.parquet']

# %%
older_dataframes = []
for old_pd in older_dataframes_paths:
    df = pd.read_parquet(BytesIO(container_client.download_blob(old_pd).readall()))
    older_dataframes.append(df)

current_table = pd.read_parquet(BytesIO(container_client.download_blob(DATA_PATH).readall()))

# %%
df.shape
# Out:
# (340174, 39)

# %%
current_table.shape
# Out:
# (340174, 39)

# %%
for df in older_dataframes:
    assert set(df['IncidentNumber'])\
        .intersection(set(current_table['IncidentNumber'])) == set(
        df['IncidentNumber'])

    assert set(df.columns) == set(current_table.columns)
    assert len(df['IncidentNumber'].unique()) <= len(
        current_table['IncidentNumber'].unique())

# %%
current_table
# Out:
#          IncidentNumber   DateOfCall  CalYear TimeOfCall  HourOfCall  \
# 0       051451-01052020  01 May 2020     2020   00:03:18           0
# 1       051452-01052020  01 May 2020     2020   00:03:32           0
# 2       051453-01052020  01 May 2020     2020   00:05:55           0
# 3       051455-01052020  01 May 2020     2020   00:25:06           0
# 4       051456-01052020  01 May 2020     2020   00:28:07           0
# ...                 ...          ...      ...        ...         ...
# 340169  060314-30042023  30 Apr 2023     2023   23:42:08          23
# 340170  060315-30042023  30 Apr 2023     2023   23:44:20          23
# 340171  060316-30042023  30 Apr 2023     2023   23:44:25          23
# 340172  060317-30042023  30 Apr 2023     2023   23:50:13          23
# 340173  060318-30042023  30 Apr 2023     2023   23:52:17          23
#
#           IncidentGroup        StopCodeDescription  \
# 0           False Alarm  False alarm - Good intent
# 1           False Alarm  False alarm - Good intent
# 2       Special Service            Special Service
# 3       Special Service            Special Service
# 4           False Alarm                        AFA
# ...                 ...                        ...
# 340169  Special Service            Special Service
# 340170             Fire             Secondary Fire
# 340171      False Alarm                        AFA
# 340172  Special Service            Special Service
# 340173  Special Service            Special Service
#
#                   SpecialServiceType   PropertyCategory  \
# 0                               None           Dwelling
# 1                               None           Dwelling
# 2               Effecting entry/exit           Dwelling
# 3       Hazardous Materials incident           Dwelling
# 4                               None           Dwelling
# ...                              ...                ...
# 340169   Animal assistance incidents       Road Vehicle
# 340170                          None  Outdoor Structure
# 340171                          None           Dwelling
# 340172         Assist other agencies           Dwelling
# 340173   No action (not false alarm)           Dwelling
#
#                                              PropertyType  ...  \
# 0                       Self contained Sheltered Housing   ...
# 1                               House - single occupancy   ...
# 2                               House - single occupancy   ...
# 3       Purpose Built Flats/Maisonettes - 10 or more s...  ...
# 4                               House - single occupancy   ...
# ...                                                   ...  ...
# 340169                                               Car   ...
# 340170                     Small refuse/rubbish container  ...
# 340171  Purpose Built Flats/Maisonettes - 4 to 9 storeys   ...
# 340172     Converted Flat/Maisonettes - 3 or more storeys  ...
# 340173  Purpose Built Flats/Maisonettes - 4 to 9 storeys   ...
#
#        FirstPumpArriving_AttendanceTime FirstPumpArriving_DeployedFromStation  \
# 0                                 180.0                               Lambeth
# 1                                 293.0                             Stratford
# 2                                 393.0                               Bromley
# 3                                 338.0                              Millwall
# 4                                 233.0                                Ealing
# ...                                 ...                                   ...
# 340169                            523.0                              Chiswick
# 340170                           1008.0                              Kingston
# 340171                            254.0                                Barnet
# 340172                            299.0                                Ealing
# 340173                            192.0                            Wandsworth
#
#        SecondPumpArriving_AttendanceTime  \
# 0                                  192.0
# 1                                  420.0
# 2                                    NaN
# 3                                  422.0
# 4                                  364.0
# ...                                  ...
# 340169                               NaN
# 340170                               NaN
# 340171                               NaN
# 340172                               NaN
# 340173                               NaN
#
#         SecondPumpArriving_DeployedFromStation  NumStationsWithPumpsAttending  \
# 0                                      Lambeth                            2.0
# 1                                  Leytonstone                            2.0
# 2                                         None                            1.0
# 3                                     Shadwell                            2.0
# 4                                        Acton                            2.0
# ...                                        ...                            ...
# 340169                                    None                            1.0
# 340170                                    None                            1.0
# 340171                                    None                            1.0
# 340172                                    None                            1.0
# 340173                                    None                            1.0
#
#        NumPumpsAttending PumpCount PumpHoursRoundUp Notional Cost (£) NumCalls
# 0                    3.0       3.0              2.0             692.0      1.0
# 1                    2.0       2.0              1.0             346.0      1.0
# 2                    1.0       1.0              1.0             346.0      2.0
# 3                    2.0       2.0              2.0             692.0      1.0
# 4                    2.0       2.0              2.0             692.0      1.0
# ...                  ...       ...              ...               ...      ...
# 340169               1.0       1.0              1.0               NaN      1.0
# 340170               1.0       1.0              1.0               NaN      1.0
# 340171               1.0       1.0              1.0               NaN      1.0
# 340172               1.0       1.0              1.0               NaN      1.0
# 340173               1.0       1.0              1.0               NaN      1.0
#
# [340174 rows x 39 columns]

# %%
from pathlib import Path

train_path = Path("../data/train.pkl")
test_path = Path("../data/test.pkl")

assert train_path.is_file()
assert test_path.is_file()

train = pd.read_pickle(train_path)
test = pd.read_pickle(test_path)
assert ((pd.to_datetime(current_table['DateOfCall']).max() -
            test['DateOfCall']).dt.days).max() <= 365
assert ((pd.to_datetime(train['DateOfCall']).max() -
            train['DateOfCall']).dt.days).max() >= 366
assert ((train['DateOfCall'].max() - train['DateOfCall']).dt.days).max() <= 1095

# %%
os.getcwd()
# Out:
# 'c:\\Users\\marcv\\OneDrive\\MLOps\\mlops_fire_fighter\\experiments'

# %%
train["DateOfCall"].max()
# Out:
# Timestamp('2022-12-31 00:00:00')

# %%
train["DateOfCall"].min()
# Out:
# Timestamp('2020-05-01 00:00:00')
